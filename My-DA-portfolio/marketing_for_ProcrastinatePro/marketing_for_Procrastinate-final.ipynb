# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Функции-для-вычисления-метрик" data-toc-modified-id="Функции-для-вычисления-метрик-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для вычисления метрик</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Маркетинговая-активность" data-toc-modified-id="Маркетинговая-активность-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинговая активность</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость" data-toc-modified-id="Общая-окупаемость-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Общая окупаемость</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Окупаемость-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Окупаемость с разбивкой по устройствам</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Окупаемость-с-разбивкой-по-регионам" data-toc-modified-id="Окупаемость-с-разбивкой-по-регионам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Окупаемость с разбивкой по регионам</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Окупаемость-с-разбивкой-по-каналам" data-toc-modified-id="Окупаемость-с-разбивкой-по-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Окупаемость с разбивкой по каналам</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Обнаруженные-проблемы" data-toc-modified-id="Обнаруженные-проблемы-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Обнаруженные проблемы</a></span><ul class="toc-item"><li><span><a href="#Конверсия" data-toc-modified-id="Конверсия-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Конверсия</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.5.1.1"><span class="toc-item-num">5.5.1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Удержание" data-toc-modified-id="Удержание-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>Удержание</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.5.2.1"><span class="toc-item-num">5.5.2.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Рекламная-активность-на-канале-TipTop" data-toc-modified-id="Рекламная-активность-на-канале-TipTop-5.5.3"><span class="toc-item-num">5.5.3&nbsp;&nbsp;</span>Рекламная активность на канале TipTop</a></span></li></ul></li></ul></li><li><span><a href="#Вывод-исследования" data-toc-modified-id="Вывод-исследования-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод исследования</a></span><ul class="toc-item"><li><span><a href="#Данные-для-анализа" data-toc-modified-id="Данные-для-анализа-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Данные для анализа</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Анализ-бизнес-показателей" data-toc-modified-id="Анализ-бизнес-показателей-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Анализ бизнес-показателей</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Эффективность маркетинга Prokrastination Pro+
# **c 1 мая по 27 октября 2019 года**

# %% [markdown]
# **Описание проекта**
#
# Prokrastination Pro+ - развлекательное приложение, активно вкладывающееся в рекламу на разных платформах. В последнее время реклама себя не оправдывает, компания терпит убытки.
#
# **Цель исследования**
#
# * Оценить результаты рекламных компаний за период с 1.05.19 по 27.10.19
# * Понять возможные причины неэффективности
#
# **Источник данных**
#
# Внутренние данные компании о пользователях, покупках, рекламных компаниях.

# %% [markdown]
# ## Подготовка данных

# %%
# Импортируем нужные библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import os
from datetime import datetime, timedelta
import numpy as np


# Добавим для игнорирования "warnings"
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Загрузим файлы

# %%
# Работа над проектом происходит локально.
# Для того, что бы  избежать ошибки при открытии файла с данными прописано два варианта пути:

files_path = ['costs_info_short.csv'   # информация о расходах на рекламу
              , 'orders_info_short.csv'   # информация о покупках
              , 'visits_info_short.csv'   # лог сервера с информацией о посещениях сайта
             ]

dfs = []
for i in range(len(files_path)):
    pth1 = files_path[i]
    pth2 = '/datasets/' + pth1

    if os.path.exists(pth1):
        df = pd.read_csv(pth1)
        dfs.append(df)
    elif os.path.exists(pth2):
        df = pd.read_csv(pth2)
        dfs.append(df)
    else:
        print('Датасет {} не найден, проверьте путь к файлу'.format(path))

costs = dfs[0]
orders = dfs[1]
visits = dfs[2]

display(costs.head(), costs.info())
display(orders.head(), orders.info())
display(visits.head(), visits.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#         User Id             Event Dt  Revenue
# ...

# %% [markdown]
# Приведем данные о дате и времени к типу `DateTime`.
# Переименуем колонки для использования готовых функций.

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

orders['Event Dt'] = pd.to_datetime(orders['Event Dt'])

visits['Session Start'] = pd.to_datetime(visits['Session Start'])
visits['Session End'] = pd.to_datetime(visits['Session End'])

orders.columns = ['user_id', 'event_dt', 'revenue']
visits.columns = ['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']
costs.columns = ['dt', 'channel', 'costs']

# %% [markdown]
# Проверим наличие пропусков в таблицах.

# %%
for file in [visits, costs, orders]:
    print('Пропуски в таблице:')
    display(file[file.isna()].count())
# Out:
# Пропуски в таблице:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64
# Пропуски в таблице:
# dt         0
# channel    0
# costs      0
# dtype: int64
# Пропуски в таблице:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %% [markdown]
# Пропусков в данных нет.
# Проверим на наличие дубликатов.

# %%
for file in [visits, costs, orders]:
    print(f'Количество дубликатов в таблице:')
    display(file.duplicated().sum())
# Out:
# Количество дубликатов в таблице:
# 0
# Количество дубликатов в таблице:
# 0
# Количество дубликатов в таблице:
# 0

# %% [markdown]
# ### Вывод
# Данные загружены и подготовлены к работе.
#
# Для анализа доступны данные без пропусков и дубликатов:
# * 1800 рекламных акций с датой проведения и каналом
# * 40212 покупок с датой и id покупателя
# * 309901 пользовательских сессий с информацией об id пользователя, регионе, канале и девайсе.

# %% [markdown]
# ## Функции для вычисления метрик

# %% [markdown]
# Определим функции для создания профилей, расчёта удержания, конверсии, LTV и ROI: `get_profiles()`, `get_retention()`, `get_conversion()` и `get_ltv()`.

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, events, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# А также функции для визуализации этих метрик — `filter_data()`, `plot_retention()`, `plot_conversion()` и `plot_ltv_roi()`.
#
# Сделаем окно сглаживания 14, для того чтобы убрать лишний шум на большом промежутке времени.

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=14):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.ylabel('Доля пользователей от новых')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.ylabel('Доля пользователей от новых')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, 
                      sharey=ax3
                     )
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=14):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.ylabel('Суммарная доля конвертированных')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=30):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.ylabel('Сумма денег, ед.')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.ylabel('Доля окупаемости')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Вывод
# Функции загружены и готовы к работе.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Построим и изучим профили пользователей.

# %%
# events - пустой список, нужен для работы функции
events = []


# получаем профили пользователей
profiles = get_profiles(visits, orders, events, costs)
display(profiles.head(5))

date_min = profiles.sort_values(by='dt').reset_index().loc[0, 'dt']
date_max = profiles.sort_values(by='dt', ascending=False).reset_index().loc[0, 'dt']
print('Минимальная дата привлечения: {}'
      .format(date_min))
print('Максимальная дата привлечения: {}'
      .format(date_max))
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769
# Минимальная дата привлечения: 2019-05-01
# Максимальная дата привлечения: 2019-10-27

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v. 2 ✔️:</b> Да, это тоже верно подмечено. Но самое основное и главное - то что мы с помощью собрали файл, от корретности которого зависти по сути результат всего исследования. Поэтому важно убедиться, что файл собран верно. Есть много способов проверить, тут авторы предложили рассмотреть дипазон привлечения. Если он совпадает с заявленным, мы понимаем, что все пользователи попали в датасет, мы никого не потеряли.

# %% [markdown]
# **Минимальная и максимальная дата привлечения совпадает с ожидаемыми. Значит файл для анализа данных собран корректно.**
#
# Максимальная дата привлечения - 27 октября.
#
# Поскольку считается, что окупаться новые пользователи должны в течение 2 недель, значит нас будет интересовать покупки за этот период. Тех пользователи, которые не успели "дожить" необходимое количество дней до текущей даты (1 октября) - необходимо будет удалить из расчета метрик.
#
# Это зашито в наши функции вычисления.

# %% [markdown]
# Для упрощения визуализации профилей новых клиентов, напишем функцию `get_pie_profilies`, которая отобразит круговые диаграммы распределений новых пользователей по различным признакам.

# %%
def get_pie_profilies(profiles, sign):
    # Создадим список стран с числом новых пользователей
    sign_table = profiles.groupby(sign).agg(
        {'user_id': 'count'}).reset_index().sort_values('user_id', ascending=False)
    # Расчитаем долю платящих в каждой стране
    sign_table['share'] = sign_table['user_id']/sign_table['user_id'].sum()

    # Создадим список стран с числом новых платящих пользователей
    sign_table_payer = profiles.query('payer==True').groupby(sign).agg(
        {'user_id': 'count'}).reset_index().sort_values('user_id', ascending=False)
    # Добавим столбец с численностью в каждой стране
    sign_table_payer = sign_table_payer.merge(sign_table, on=sign, how='left')
    # Расчитаем долю для каждой страны
    sign_table_payer['share'] = sign_table_payer['user_id_x']/sign_table_payer['user_id_y']

    # Визуализируем
    plt.figure(figsize=(15, 5))

    ax1 = plt.subplot(1, 2, 1)
    ax1.pie(sign_table['share']
        , autopct='%1.1f%%'
        , labels=sign_table[sign]
        )
    plt.title('Распределение новых пользователей')

    ax2 = plt.subplot(1,2,2)
    ax2.bar(sign_table_payer[sign], sign_table_payer['share'].sort_values(ascending=False)*100)
    plt.title('Доля новых платящих пользователей')
    plt.ylabel('Доля, %')
    plt.xticks(rotation=-45)
    plt.show()

# %% [markdown]
# Изучим, как новые пользователи приложения распределяются по **странам**. Сделаем анализ для всех и отдельно для платящих пользователей.

# %%
get_pie_profilies(profiles, 'region')

# %% [markdown]
# **Вывод**
#
# * Две трети новых пользователей из США, и по 10% из Великобретании, Германии и Франции.
# * В США самая большая доля платящих среди всех новых пользователей - почти 7%, остальные страны имеют примерно равные доли 4%.

# %% [markdown]
# Изучим, как новые пользователи приложения распределяются по **каналам привлечения**. Сделаем анализ для всех и отдельно для платящих пользователей.

# %%
get_pie_profilies(profiles, 'channel')

# %% [markdown]
# **Вывод**
#
# * Более 35% новых пользователей приходят самостоятельно.
# * FaceBoom и TipTop привлекают наибольшее число новых пользователей (около 20% и 13% соответственно).
# * Распределение доли платящих среди всех новых пользователей также неодинаково: больше всего на каналах FaceBoom и TipTop - 12% и 11% соответственно. Меньше всего у MediaTornado - около 2%.

# %% [markdown]
# Изучим, как новые пользователи приложения распределяются по **устройствам**. Сделаем анализ для всех и отдельно для платящих пользователей.

# %%
get_pie_profilies(profiles, 'device')

# %% [markdown]
# **Вывод**
#
# * Около 35% новых пользователей пользуются iPhone.
# * Остальные устройства: Android, PC, Mac - распределены равномерно среди 65%
# * Доли платящих среди всех новых пользователей приблизительно равны по устройствам - несколько меньше на PC.

# %% [markdown]
# ### Вывод
# * Новые пользователи привлекались с 1 мая по 27 октября 2019 года.
# * Две трети новых пользователей из США, и по 10% из Великобретании, Германии и Франции.
# * Более 35% новых пользователей приходят самостоятельно. Из платных каналов FaceBoom и TipTop привлекают наибольшее число новых пользователей.
# * Распределение доли платящих пользователей сильно различается по каналам.
# * Распределение по устройствам более-менее равномерно, доли платящих пользователей приблизительно одинаковые.
# * Доля платящих пользователей среди новых в США почти в два раза выше, чем в остальных регионах и составляет 7% против 4% у остальных.

# %% [markdown]
# ## Маркетинговая активность

# %% [markdown]
# Выясним, сколько денег потратили **всего**?

# %%
costs_total = round(costs['costs'].sum(), 2)
print('Всего в период с {} по {} на маркетинг потрачено {}'
      .format(date_min, date_max, costs_total))
# Out:
# Всего в период с 2019-05-01 по 2019-10-27 на маркетинг потрачено 105497.3

# %% [markdown]
# Выясним, сколько денег потратили **на каждый источник**?

# %%
# Расчитаем для каждой страны суммарную стоимость
costs_by_channel = costs.groupby('channel').agg(
        {'costs': 'sum'}).reset_index().sort_values('costs', ascending=False)
# и долю
costs_by_channel['share'] = costs_by_channel['costs']/costs_total

# визуализируем
plt.pie(costs_by_channel['costs']
        , autopct='%1.1f%%'
        , pctdistance=1.2
        )
plt.title('Объем маркетинговых затрат по канналам привлечения')
plt.legend(bbox_to_anchor = (-0.16, 0.7, 0.25, 0.25),
    loc = 'best', labels = costs_by_channel['channel'] + '\n' +
                round(costs_by_channel['costs'], 2).astype('str'))
plt.show()

# %% [markdown]
# В TipTop вложено больше других канналов (52%), на втором месте FaceBoom (31%). Остальные канналы суммарно составляют 17% завтрат.

# %% [markdown]
# Выясним, сколько денег потратили **по времени**?

# %%
costs_by_time = costs.groupby('dt').agg({'costs': 'sum'})
costs_by_time.plot(grid=True, legend=False, xlabel='Дата')
plt.title('Динамика маркетинговых затрат')
plt.ylabel('Суммарные траты на рекламу в день, ед')
plt.show()

# %% [markdown]
# Стоимость рекламы постепенно росла за период исследования.

# %% [markdown]
# Оценим, сколько в среднем стоило привлечение **одного покупателя в среднем и из каждого источника**?
# Для расчетов исключим органиков, поскольку компания не тратила ресурсы на их привлечение.

# %%
# Посчитаем все затраты на рекламу
# Разделим на число новых пользователей не "органиков"
cost_per_user_mean = costs_total/len(profiles.query(
                    'channel != "organic"')['user_id'].unique())
print(f'Средняя стоимость привлечения пользователей: {cost_per_user_mean: .2}')

# И отдельно стоимость привлечения плятящих
cost_per_payer_mean = costs_total/len(profiles.query(
                    'channel != "organic" and payer==True')['user_id'].unique())
print(f'Средняя стоимость привлечения платящих пользователей: {cost_per_payer_mean: .2}')
# Out:
# Средняя стоимость привлечения пользователей:  1.1
# Средняя стоимость привлечения платящих пользователей:  1.4e+01

# %% [markdown]
# Стоимость привлечения платящих пользователей более чем в 10 раз больше, что соответствует их доле.

# %%
# Оценим среднюю стоимость по таблице профилей
# Сделаем сортировку по payer - нас интересуют покупатели
cost_per_payer_by_channel = (
profiles.query('payer==True').groupby('channel').agg(
    {'acquisition_cost': 'mean'}
    ).sort_values(
    by='acquisition_cost', ascending=True
    ))
cost_per_payer_by_channel.plot(kind = 'barh', legend=False)
plt.title('Средняя стоимость привлечения покупателя по канналам')
plt.ylabel('Канал привлечения')
plt.show()
cost_per_payer_by_channel.sort_values(by='acquisition_cost', ascending=False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.785961
# FaceBoom                    1.113243
# AdNonSense                  1.011119
# lambdaMediaAds              0.735322
# WahooNetBanner              0.600576
# RocketSuperAds              0.418493
# OppleCreativeMedia          0.250456
# MediaTornado                0.217389
# YRabbit                     0.211338
# LeapBob                     0.210378
# organic                     0.000000

# %%
# Построим динамику объема рекламных трат по канналам привлечения
costs_by_time = costs.pivot_table(
    index='dt', columns='channel', values='costs', aggfunc='sum'
)
# Усредним значения с помощью функции filter_data
# filter_data(costs_by_time, 7).plot(grid=True, figsize=(10,5))
costs_by_time.plot(grid=True, figsize=(10,5))
plt.ylabel('Траты, ед.')
plt.title('Динамика суммарных маркетинговых затрат')

plt.show()

# %% [markdown]
# Самый дорогой каннал привлечения - TipTop, второй - FaceBoom - более чем в два раза дешевле.
#
# Объем трат на рекламу на канналах TipTop и FaceBoom сильно возрастает со временем, остальные канналы по тратам стабильны во времени.

# %% [markdown]
# ### Вывод
# * Всего в период с 2019-05-01 по 2019-10-27 на маркетинг потрачено 105497.3
# * В TipTop вложено больше других канналов (52%), на втором месте FaceBoom (31%). Остальные канналы суммарно составляют 17% завтрат.
# * Стоимость рекламы постепенно росла за период исследования.
# * Самый дорогой каннал привлечения - TipTop, второй - FaceBoom - более чем в два раза дешевле.

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# ### Общая окупаемость

# %% [markdown]
# Проанализируем общую окупаемость рекламных компаний.
#
# Учтем, что текущая дата: 1-го ноября 2019 года.
#
# Принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей - значит горизонт анализа зададим 14 дней.
#
# Для этого анализа будем считать метрики без органических пользователей.
#
# Расчет метрик будем проводить без включения "органиков" - для этого заного рассчитаем профили.

# %%
profiles = get_profiles(visits.query('channel != "organic"'), orders, events, costs)
display(profiles.head(5))
# Out:
#     user_id            first_ts     channel   device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom   iPhone  United States
# 2  22593348 2019-08-22 21:35:48  AdNonSense       PC        Germany
# 3  31989216 2019-10-02 00:07:44     YRabbit   iPhone  United States
# 4  46006712 2019-06-30 03:46:29  AdNonSense  Android         France
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.076596
# 1  2019-07-09 2019-07-01  False          1.092857
# 2  2019-08-22 2019-08-01  False          0.988235
# 3  2019-10-02 2019-10-01  False          0.214286
# 4  2019-06-30 2019-06-01   True          1.008000

# %%
# Зададим момент и горизонт анализа
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# LTV среднего пользователя растет, значит все рассчитано правильно.
#
# Динамика LTV 14-го дня остается практически неизменной за все время исследования.
# Это говорит о том, что "качество"новоприходящих пользователей не меняется.
#
# Резко возрос после *15 июля* показатель CAC - стоимость привлечения одного пользователя, усредненная по всем платформам за все акции. После чего также продолжал менее интенсивный рост.
# Вероятно, в районе этой даты произошло лимо изменение маркетинговой стратегии, либо качественное изменение привлеченных пользователей (например, уменьшение конверсии или удержания из-за технических неполадок). *Этот момент необходимо детально проанализировать.*
#
# Усредненное ROI на 12 лайфтайм преодолевает единичное значение. Значит, теоретически, заданная компанией цель выполняется.
#
# Но динамика ROI в течение всего времени показывает его сильное падение. Если в начале периода ROI на 14 лайфтайм был сильно меньше 1, после *июля* он упал ниже и к концу периода составил менее 0.8. Это объясняет убытки компании.

# %% [markdown]
# #### Вывод
# * Средние метрики на первый взгляд показывают хорошие значения: LTV не падает за период изучения, средний ROI становится больше 1 на 12 лайфтайм.
#
# * Но сочетание возрастающего CAC в начале лета и неизменного LTV приводит к постепенному падению ROI до значений ниже 0.8 на конец изучаемого периода.

# %% [markdown]
# #### Вывод
#
# Изменение в поведении органиков не может объяснять нарастающие убытки компании.

# %% [markdown]
# ### Окупаемость с разбивкой по устройствам

# %% [markdown]
# Для того, что бы оценить, связано ли падение ROI с отдельными устройствами, проанализаруем метрики для каждого устройства.
# Также, этот анализ сможет выявить возможные проблемы, связанные с технической работой на отдельных типах устройств.
#
# Вспомним, что на iPhone на 15% больше новых платящих пользователей, чем на остальных устройствах, Mac немного отстает от остальных.

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# 1. LTV постоянно растет для всех устройст - хорошо.
#
# В течение периода исследования LTV различных устройст несколько повышается в конце мая - начале июля, после чего остается стабильным, с учетом сезонных колебаний.
#
# Для iPhone и Mac LTV несколько выше на все лайфтаймы, для PC LTV в среднем несколько ниже. Различия нормальные, не говорят о наличии проблем.
#
# 2. CAC для различных устройст сильно отличается. Значит, пользователи с разными устройставми по разному привлекались различными рекламными компаниями. Скорее всего тут вопрос охвата платформ на разных устройставх.
#
# Но форма CAC для разных устройст остается одинаковой. Для всех наблюдается резкий рост с начала июня, который был отмечен ранее.
#
# 3. Пользователи на iPhone и Mac в среднем не окупаются на 14 лайфтайм. В начале периода исследования ROI для iPhone, PC, Android был около 1.2-1.4. Для iPhone, Android и Mac ROI с начала июня опустился ниже 1. Можно установить, что это является серьезной, хотя и не единственной проблемой.
#
# Самый позитивный ROI у пользователей на PC - в среднем они окупаются на 6 день. В динамике ROI не опускается ниже 1, хотя значительно падает за период исследования.
#
# Пользователи на Android занимают среднее положение.

# %% [markdown]
# #### Вывод
# * Клиенты на iPhone и Mac оказываются самыми проблемными - средняя стоимость их привлечения самая высокая и сильно растет со временем, что приводит к критичному падению ROI. Вероятная причина - неэффективные маркетинговые компании в период с конца мая по июнь.
#
# * Наиболее успешные пользователи на PC, хотя для них ROI также падает, но не опускается ниже 1.

# %% [markdown]
# ### Окупаемость с разбивкой по регионам

# %% [markdown]
# Проанализаруем метрики для каждого региона.
#
# Вспомним, что более 2/3 новых пользователей приходится на США.

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# 1. LTV постоянно растет для всех регионов, но для США оказывается стабильно выше для любого лайфтайми и даты. LTV остальных стран приблизительно равны, у Франции немного медленнее растет.
#
# Ввозможно, большие значения LTV для США привели к идее для этой страны наращивать объем маркетинговой активности.
#
# 2. CAC для США оказывается изначально в два раза выше, чем для других стран, и стоимость привлечения клиентов со временем очень значительно возрастает.
#
# Именно CAC для США обеспечивает форму кривой, усредненной по регионам.
# Для остальных регионов в июне CAC уменьшается - видимо было принято решение сосредоточится на рекламе в США, уменьшив ее в других регионах.
#
# 3. ROI США не достигает 1 (остается в районе 0.8). ROI остальных стран оказывается больше 1 на 2-4 день.
#
# В динамике, для Франции, Германии и Великобритании ROI 14-го дня не опускается ниже 1 ни разу за исследованный период.
# ROI 14-го дня для США снижается ниже 1 в конце июня.
#
# 4. Сопоставляя данные с анализом по устройствам, можно предположить, что проблема именно в поведении пользователей из США на iPhone и Mac.

# %% [markdown]
# #### Вывод
# * LTV для США оказывается стабильно выше для любого лайфтайми и даты. LTV остальных стран приблизительно равны.
# * CAC для США оказывается изначально в два раза выше остальных, и стоимость привлечения клиентов со временем очень значительно возрастает.
# * ROI США не достигает 1 (остается в районе 0.8). ROI остальных стран оказывается больше 1 на 2-4 день.
# * Вероятно, проблема именно в поведении пользователей из США на iPhone и Mac.

# %% [markdown]
# ### Окупаемость с разбивкой по каналам

# %% [markdown]
# Теперь проанализируем клиентов с разбивкой по каналам.
#
# Согласно предварительному анализу, стоимость привлечения клиентов на TipTop самая высокая.

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# 1. LTV постоянно растет для всех канналов. Но по форме кривой они сильно различаются.
#
# Самый большой рост показывают LambdaMediaAds и TipTop - значительный рост к 14-му лайфтайму. За исследуемый период эти канналы показывают также стабильно высокие показатели.
#
# FaceBoom и AdNonSence показывают высокие показатели в первые дни после подписки, но не растут, как и остальные.
#
# 2. CAC для различных каналов оказывается сильно разным, но для большинства сатабильным.
#
# CAC каннала TipTop значительно возрастает с течением времени. Скорее всего, в этом и заключается ключевая проблема.
#
# Стоимость привлечения на каналах FaceBoom и AdNonSence на втором месте.
#
# 3. Два канала: TipTop, FaceBoom не показывают ROI выше 1 на 14-й лайфтайм. AdNonSence преодолевает 1, но незначительно. Остальные каналы показывают прибыль с 2-го по 7-й лайфтафмы.
#
# В динамике картина примерно такая же. Почти все канналы показывают ROI выше 1 на всем периоде исследования.
# TipTop, FaceBoom и AdNonSence оказываются убыточными.
#
# Каналы YRabbit и MedisTornado показывают окупаются с первой клиентской сессии и показывают высокий ROI на протяжении всего периода исследования.

# %% [markdown]
# #### Вывод
# * LTV для каналов LambdaMediaAds и TipTop показывает значительный рост после первого привлечения.
# * CAC канала TipTop значительно возрастает с течением времени. Стоимость привлечения на канналах FaceBoom и AdNonSence на втором месте.
# * Три канала: TipTop, FaceBoom и AdNonSence не показывают ROI выше 1 на 14-й лайфтайм. Остальные канналы показывают прибыль с 2-го по 7-й лайфтафмы.
# * Каналы YRabbit и MedisTornado показывают окупаются с первой клиентской сессии и показывают высокий ROI на протяжении всего периода исследования.

# %% [markdown]
# ### Обнаруженные проблемы

# %% [markdown]
# После анализа различных групп пользователей можно выявить три возможные проблемы:
#
# 1. Регион
#
# **В США наблюдается критический рост CAC, что приводит к их убыточности.**
#
# Остальные регионы оказываются в плюсе, но поскольку более 2/3 новых пользователей приходится на США, это отбрасывает компанию в минус.
#
# 2. Платформа
#
# **CAC канала TipTop значительно возрастает с течением времени.** Стоимость привлечения на каналах FaceBoom и AdNonSence на втором месте.
#
# 3. Устройство
#
# **Пользователи на iPhone и Mac не окупаются на 14 лайфтайм.** При этом в начале периода исследования ROI iPhone был около 1.4, но сильно упал и стабильно ниже с конца июня.

# %% [markdown]
# Проанализируем, в чем может быть причина.
#
# Изучим конверсию и удержание пользователей из США, пользователей с каналов TipTop, FaceBoom и AdNonSence. Дополнительно проверим разбивку по устройствам.

# %% [markdown]
# #### Конверсия

# %% [markdown]
# Посмотрим, как каналы распределены по регионам. Посчитаем новых пользователей.

# %%
# Посчитаем, сколько пользователей с каналов для стран
region_channel_user = profiles.pivot_table(
    index='region', columns='channel', values='user_id', aggfunc='nunique'
    ).fillna(0)

# Найдем процент от всех пользователей в стране
round(region_channel_user.div(region_channel_user.sum(axis=1), axis=0), 1)*100
# Out:
# channel        AdNonSense  FaceBoom  LeapBob  MediaTornado  \
# region
# France               10.0       0.0     30.0           0.0
# Germany              10.0       0.0     30.0           0.0
# UK                   10.0       0.0     30.0           0.0
# United States         0.0      50.0      0.0          10.0
#
# channel        OppleCreativeMedia  RocketSuperAds  TipTop  WahooNetBanner  \
# region
# France                       30.0             0.0     0.0            30.0
# Germany                      30.0             0.0     0.0            30.0
# UK                           30.0             0.0     0.0            30.0
# United States                 0.0            10.0    30.0             0.0
#
# channel        YRabbit  lambdaMediaAds
# region
# France             0.0            10.0
# Germany            0.0            10.0
# UK                 0.0            10.0
# United States     10.0             0.0

# %% [markdown]
# При анализе активности пользователей на платформах важно помнить, что каналы для регионов не пересекаются!

# %%
# смотрим конверсию с разбивкой по каналам
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим конверсию с разбивкой по странам
dimensions = ['region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим конверсию с разбивкой по устройствам
dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим конверсию с разбивкой по устройствам
# оценим только пользователей из США
dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('region == "United States"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим конверсию с разбивкой по каналам
# оценим только пользователей из США
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('region == "United States"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим конверсию с разбивкой по каналам
# оценим только пользователей из США
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('region != "United States"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# ##### Выводы
# 1. Разные каналы привлечения обладают сильно различающимися уровнем конверсии. Существенных проблем по разным канналам нет.
#
# TipTop, FaceBoom, LambdaMediaAds и AdNonSence обладают наилучшей конверсией.
#
# 2. Конверсия в США значительно выше, чем в других регионах. Значительных проблем по регионам нет.
#
# 3. Конверсия для пользователей на PC значительно ниже, чем на других платформах.
# * Возможно, это эффект технических проблем - неудобство оплаты, меньший функционал и др.
# * Вторая версия - каналы, на которых рекламируется приложение - это тоже приложения, устанавливающиеся на смартфон, а с PC в эти каналы заходят реже.
#
# 4. Пользователи из США на различных устройствах не демонстрируют существенных проблем с конверсией.
#
# 5. В США представлены только 5 каналов. TipTop, FaceBoom и RocketSuperAds конвертируются лучше других.

# %% [markdown]
# #### Удержание

# %%
# смотрим удержание с разбивкой по канналам привлечения
dimensions = ['channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
# смотрим удержание с разбивкой по регионам
dimensions = ['region']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Проверим, что низкое удержание платящих пользователей из США связано с тем, что там много пользователей на FaceBoom, с которой проблемы.

# %%
# смотрим удержание с разбивкой по регионам
dimensions = ['region']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('channel != "FaceBoom"'), visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Действительно, при исключении платформы FaceBoom удержание в САШ на уровне и даже выше остальных стран.

# %%
# смотрим удержание с разбивкой по устройствам
dimensions = ['device']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
# смотрим удержание с разбивкой по устройствам
# Только пользователи из США
dimensions = ['device']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('region == "United States"'), visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %%
# смотрим удержание с разбивкой по каналам
# Только пользователи из США
dimensions = ['channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('region == "United States"'), visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# ##### Выводы
# 1. Удержание платящих пользователей на платформах FaceBoom и AdNonSence значительно ниже остальных. Также в течение периода удержание на 14-й день на этих платформах остается стабильно низким.
#
# Это является ключевой проблемой в убытках компании - низкое удержание платящих пользователей на одной из самых популярных платформ.
#
# 2. Удержание платящих пользователей в США несколько ниже, чем в остальных регионах.
#
# Это связано только тем, что в США наибольший процент пользователей с FaceBoom, на которой проблемы.
#
# 3. Заметных проблем с удержанием на различных устройствах нет.
#
# 4. Сложностей с пользователями из США на различных устройствах не демонстрируют существенных проблем с удержанием.

# %% [markdown]
# #### Рекламная активность на канале TipTop

# %% [markdown]
# Покажем, как менялась сумма рекламных трат по каналам, с группировкой по месяцам.

# %%
# Добавим столбец с месяцем
costs['month'] = pd.to_datetime(costs['dt']).dt.month

# Построим динамику объема рекламных трат по канналам привлечения
costs_by_time = costs.pivot_table(
    index='month', columns='channel', values='costs', aggfunc='sum'
)

costs_by_time.plot(grid=True, figsize=(10,5))
plt.ylabel('Траты, ед.')
plt.title('Динамика суммарных маркетинговых затрат')

plt.show()

# %% [markdown]
# Как показало исследование CAC и ROI по платформам - стоимость привлечения одного пользователя на канале TipTop сильно растет со временем. При этом, LTV высокое, но не достаточно, что бы компенсировать затраты на рекламу.
#
# Удержание и конверсия пользователей на канале TipTop находится на уровне остальных каналов, несмотря на маркетинговую активность.
#
# Можно сделать вывод о неоправданности увеличения трат на рекламу на канале TipTop.
# Если при уменьшении трат, удержание или конверсия новых пользователей начнет падать, необходимо пересмотреть рекламную компанию.

# %% [markdown]
# ## Вывод исследования

# %% [markdown]
# ### Данные для анализа
# 1. Для анализа доступны данные без пропусков и дубликатов:
#
# * 1800 рекламных акций с датой проведения и каналом
# * 40212 покупок с датой и id покупателя
# * 309901 пользовательских сессий с информацией об id пользователя, регионе, канале и девайсе.
#
# 2. Период исследования с 2019-05-01 по 2019-10-27

# %% [markdown]
# ### Анализ данных
#
# * Новые пользователи привлекались с 1 мая по 27 октября 2019 года.
# * Две трети новых пользователей из США, и по 10% из Великобретании, Германии и Франции.
# * Более 35% новых пользователей приходят самостоятельно. Из платных каналов FaceBoom и TipTop привлекают наибольшее число новых пользователей.
# * Распределение доли платящих пользователей сильно различается по каналам.
# * Распределение по устройствам более-менее равномерно, доли платящих пользователей приблизительно одинаковые.
# * Доля платящих пользователей среди новых в США почти в два раза выше, чем в остальных регионах и составляет 7% против 4% у остальных.

# %% [markdown]
# ### Анализ бизнес-показателей
#
# **Основная проблема**
#
# 1. Низкое удержание платящих пользователей на одной из самых популярных платформ - FaceBoom.
# Также низкое удержание платящих на менее популярной платформе - AdNonSence.
# * Такой эффект может быть связан с техническими неполадками - при переходе с определенной платформы приложение не подключается или подключается плохо.
# * Возможная причина - неоправданные ожидания - реклама на платформе обещает что-то, что пользователь не видит в приложении.
# * Другая гипотеза - навязчивая реклама, которую платформа загружает при переходе по ссылке.
#
# 2. Траты на рекламу на канале TipTop неоправдано высоки.
# Если при уменьшении трат, удержание или конверсия новых пользователей начнет падать, необходимо пересмотреть рекламную компанию.
#
# **Перспективные пути маркетинговой активности**
#
# 1. Пользователи из США обладают наибольшей конверсией, это может стать перспективным направлением экстенсивного расширения.
#
# 2. LambdaMediaAds - каннал с хорошей конверсией, практически не охваченный рекламой. Можно расширяться в этом направлении. Но канал не представлен в США. Необходимо провести исследование - можно ли его задействовать и в США.
# 3. RocketSuperAds - каннал с хорошей конверсией в США. Можно расширять рекламную деятельность.
#
# **Обратить внимание**
#
# 1. Низкая конверсия пользователей на PC - это может быть:
# - эффект технических проблем - неудобство оплаты, меньший функционал и др.
# - основной канал рекламы через приложения на смартфоне, значит PC не охвачен. Можно подумать над расширением рекламы на PC - в браузере, онлайн кинотеатрах, поисковиках, например.
